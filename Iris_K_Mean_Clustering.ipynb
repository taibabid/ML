# %% [markdown]
# <a href="https://colab.research.google.com/github/taibabid/ML/blob/main/Iris_K_Mean_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.datasets import make_blobs # La fonction make_blobs permet de simuler des clusters dans un Dataset.
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans

# %% [markdown]
# # Charger les données

# %%
iris = load_iris() 
X = iris.data 
y = iris.target
plt.scatter(X[:,0], X[:,1])

# %% [markdown]
# # Entrainer le modele de K-mean Clustering

# %%
model = KMeans(n_clusters=3) 
model.fit(X)
# Out:
# KMeans(n_clusters=3)

# %% [markdown]
# # Visualiser les Clusters

# %%
predictions = model.predict(X) 
plt.scatter(X[:,0], X[:,1], c=predictions)
